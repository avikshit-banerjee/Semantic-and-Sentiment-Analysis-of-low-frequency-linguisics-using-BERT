# %%
import re
import numpy as np
import pandas as pd
import requests
from pprint import pprint


import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
corpus_path = '/content/need_passives.csv'
df = pd.read_csv(corpus_path)
df.head()

# %%
# Dropping unwanted columns
data = df.iloc[:,2:3]
data.head()
# Out:
#                                                 text
# 0  I NEED a proper tube bender and welder torch g...
# 1  Stop Pressing rewind on the things that you NE...
# 2  Day 432 Goodmorning people of this beautiful P...
# 3  wussydoc JennyMarra A whole lotta questions NE...
# 4  Taylorbcafc It s on red tv 599 for themonth Bu...

# %%
tweets = data.text.values.tolist()
tweets

# %% [markdown]
# ### Using Hugging Face through Inference API

# %%
model = "cardiffnlp/twitter-roberta-base-sentiment-latest"
hf_token = "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"

# %% [markdown]
# Creating the API call using the model id and hf_token:

# %%
API_URL = "https://api-inference.huggingface.co/models/" + model
headers = {"Authorization": "Bearer %s" % (hf_token)}

def analysis(data):
    payload = dict(inputs=data, options=dict(wait_for_model=True))
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

# %%
sent = analysis(tweets[2])[0]
sent
# Out:
# [{'label': 'Negative', 'score': 0.031469542533159256},
#  {'label': 'Neutral', 'score': 0.3323918581008911},
#  {'label': 'Positive', 'score': 0.6361385583877563}]

# %%
max(sent, key=lambda x: x['score'])
# Out:
# {'label': 'Positive', 'score': 0.6361385583877563}

# %% [markdown]
# ### Performing Sentiment Analysis on each tweet

# %%
tweets_analysis = []
for tweet in tweets:
    try:
        sentiment_result = analysis(tweet)[0]
        top_sentiment = max(sentiment_result, key=lambda x: x['score']) # Get the sentiment with the higher score
        tweets_analysis.append({'tweet': tweet, 'sentiment': top_sentiment['label']})
 
    except Exception as e:
        print(e)

# %%
pd.DataFrame(tweets_analysis)

# %%
# Load the data in a dataframe
pd.set_option('max_colwidth', None)
pd.set_option('display.width', 3000)
df = pd.DataFrame(tweets_analysis)
 
df
# Out:
#                                                                                                                                         tweet sentiment
# 0                    Stop Pressing rewind on the things that you NEEDS to be deleted from Your $ Life Your $ past doesn t have your $ Healin   Negative
# 1                            Day 432 Goodmorning people of this beautiful Planet Only one question we NEED to be answered todayWHERE IS  THA   Positive
# 2                           wussydoc JennyMarra A whole lotta questions NEED to be asked Why was so much money spent trashing NhsG s clinica   Negative
# 3                                                               Taylorbcafc It s on red tv 599 for themonth But NEEDS to be done before 645pm   Neutral
# 4                           People say that VAR is  running football but diving is  just as much an issue Something NEEDS to be done about it  Negative
# ...

# %%
# Show a tweet for each sentiment
display(df[df["sentiment"] == 'Positive'].head(1))
display(df[df["sentiment"] == 'Neutral'].head(1))
display(df[df["sentiment"] == 'Negative'].head(1))
# Out:
#                                                                                                               tweet sentiment
# 1  Day 432 Goodmorning people of this beautiful Planet Only one question we NEED to be answered todayWHERE IS  THA   Positive
#                                                                            tweet sentiment
# 3  Taylorbcafc It s on red tv 599 for themonth But NEEDS to be done before 645pm   Neutral
#                                                                                                                       tweet sentiment
# 0  Stop Pressing rewind on the things that you NEEDS to be deleted from Your $ Life Your $ past doesn t have your $ Healin   Negative
